# %% [markdown]
# # vim常用复制粘贴命令
#
# Vim的复制粘贴命令无疑是 y,p,加上yy,P
#
# PS(附言:postscript):
#
#     Vim中有一个很有意思的约定,就是某个命令的大小写都是实现某种功能,只是方向不同,比如:
#    > w :跳转到下一个world, W :跳转到上一个world
#    >
#    > f 某行正方向查找并跳转, F :反向查找并跳转
#
# 然后部分双写的字母有行操作:
#
# > yy :复制一行
# >
# > dd :删除一行
#
# 所以：
#
# > p 就是在当前光标后粘贴, P 就是子啊当前光标前粘贴
#
#
# # Vim的寄存器和系统剪贴板
#
# ### 寄存器简介
#
# vim的强大之处之一就是自带一堆寄存器,每个寄存器独立使用.你可以在不同寄存器中存储不同数据,命令.你可以把这想象成一个加强版的剪贴板,当然它的功能不止剪贴板这么简单.
#
# 根据官方手册:vim有9种寄存器
#
# 1. The unnamed register ""
# 2. 10 numbered registers "0 to "9
# 3. The small delete register "-
# 4. 26 named registers "a to "z or "A to "Z
# 5. four read-only registers ":, "., "% and "#
# 6. the expression register "=
# 7. The selection and drop registers "*, "+ and "~
# 8. The black hole register "_
# 9. Last search pattern register "/
#
# **解释**
# 1. 无名寄存器(unnamed): "" ,缓存最后一次操作内容;
# 2. 数字寄存器(numbered): "0~9",缓存最近操作内容,复制与删除有别,"0 寄存器缓存最近一次复制的内容, "1-"9 缓存最近9次删除的内容;
#
# 7. 选择及拖拽寄存器(selection and drop): "* , "+ , "~ ,存取GUI选择文本,可用于与外部应用交互,使用前提为系统剪切板(clipboard)可用;
#
# **使用方式就是:**
# 1. 在vim中使用 "+等命令调用寄存器,然后使用 复制剪切等命令将内容操作到寄存器中.
# 2. 在vim之外的地方使用 正常的粘贴命令即可将 寄存器中的内容粘贴下来

# %% [markdown]
# # vimtutor第四讲
#
# 输入数字 + G ：则直接跳转到指定行;
#
# gg :　跳转到文件第一行;
#
# G ：跳转到文件最后一行;
#
# / +　字符串　： 在当前文件中查找改字符串(n键向下询,N向上询);
#
# ### 替换命令
#
# :s/old/new/g : 替换光标所在行的匹配字符串;
#
# :#,#s/old/new/g : 其中#,# 代表的是替换操作的若干行中的首位两行的行号,将old替换为new;
#
# :%s/old/new/g : 替换整个文件中的每个匹配字符串;
#
# :%s/ols/new/gc : 会找到整个文件中的每一个匹配字符串,并且提示是否进行替换;

# %% [markdown]
# # vimtutor第五讲
#
# :!然后接着输入一个外部命令加回车就可以执行该外部命令;
#
# :w filename : 以filename保存整个文件;
#
# ### 选择性保存命令
#
# 1. 移动光标到目标起始行;
# 2. 接着按 v 键,将光标移动至目标结尾行,你会注意到之间的文本被高亮了;
# 3. 然后按 : 字符 ,你讲看到屏幕底部会出现 :'<,'> ;
# 4. 现在请输入 w filename ,其中filename是一个未被使用的文件名;
# 5. 这时 Vim 会将选中的文本写入到 filename 命名的文件中去;
#
# ### 向当前文件插入另外的文件的内容
#
# :r filename : 将filename中的内容插入到光标所在的位置;
#
# 提示:您还可以读取外部命令的输出;
#
# :r !ls  可以将ls命令执行的结果插入到光标下面;

# %% [markdown]
# # vimtutour第六讲
#
# 输入小写的 o 会在光标下方打开新的一行,并且进入插入模式;
#
# 输入大写的 Ｏ　会在光标上方打开新的一行，并且进入插入模式；
#
# ｗ　从当前光标位置跳到下一个单词起始处；
#
# ｅ　从当前光标位置直到单词末尾；
#
# 输入小写的　ａ　则在光标之后插入文本；
#
# 输入大写的　Ｒ　则是连续替换；
#
# ### 设置选项
#
# 输入 :set xxx 可以设置 xxx 选项;
#
# 'ic' 'ignorecase' 查找时忽略字母大小写;
#
# 'is' 'incsearch' 查找短语时显示部分匹配;
#
# 'hls'  'hlsearch' 高亮显示所有的匹配短语;
#
# 选项名可以用完整版本,也可以使用缩略版本;
#
# 在选项前加上 no 可以关闭选项,如:
#
# :set noic  关闭忽略大小写;
